# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("Retail_Transactions_2000.csv")
df.head()
# Out:
#   TransactionID CustomerID  Gender  Age       City ProductCategory  Quantity  \
# 0        T00001      C2824  Female   33  Bengaluru         Fashion         3
# 1        T00002      C1409   Other   20       Pune           Books         5
# 2        T00003      C5506   Other   47       Pune       Furniture         1
# 3        T00004      C5012   Other   21  Hyderabad       Groceries         5
# 4        T00005      C4657  Female   41    Chennai          Sports         1
#
#    Price PurchaseDate PaymentMode  TotalAmount
# 0   4479   2023-03-15        Cash        13437
# 1   1051   2023-01-22        Card         5255
# 2    111   2023-04-18      Wallet          111
# 3   2946   2023-08-09        Cash        14730
# 4   3123   2023-09-23      Wallet         3123

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    2000 non-null   object
#  1   CustomerID       2000 non-null   object
#  2   Gender           2000 non-null   object
#  3   Age              2000 non-null   int64
#  4   City             2000 non-null   object
#  5   ProductCategory  2000 non-null   object
#  6   Quantity         2000 non-null   int64
#  7   Price            2000 non-null   int64
#  8   PurchaseDate     2000 non-null   object
#  9   PaymentMode      2000 non-null   object
#  10  TotalAmount      2000 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 172.0+ KB
#                Age     Quantity       Price   TotalAmount
# count  2000.000000  2000.000000  2000.00000   2000.000000
# mean     44.679000     2.957000  2496.61000   7307.414500
# ...

# %%
df.isnull().sum()
# Out:
# TransactionID      0
# CustomerID         0
# Gender             0
# Age                0
# City               0
# ProductCategory    0
# Quantity           0
# Price              0
# PurchaseDate       0
# PaymentMode        0
# TotalAmount        0
# dtype: int64

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'Gender', 'Age', 'City',
#        'ProductCategory', 'Quantity', 'Price', 'PurchaseDate', 'PaymentMode',
#        'TotalAmount'],
#       dtype='object')

# %%
df['TotalAmount'] = df['Quantity'] * df['Price']
df['TotalAmount'].sum()
# Out:
# 14614829

# %%
top_products = df.groupby("ProductCategory")["TotalAmount"].sum().sort_values(ascending=False).head(10)

plt.figure()
top_products.plot(kind="bar")
plt.title("Top 10 ProductCategory by Sales")
plt.show()

# %%
df["PurchaseDate"] = pd.to_datetime(df["PurchaseDate"])
daily_sales = df.groupby("PurchaseDate")["TotalAmount"].sum()

plt.figure()
daily_sales.plot()
plt.title("Daily Sales Trend")
plt.show()

# %%
category_sales = df.groupby("PaymentMode")["TotalAmount"].sum()

plt.figure()
category_sales.plot(kind="bar")
plt.title("payment by Category")
plt.show()

# %%
plt.figure()
sns.histplot(df["Price"], bins=20)
plt.title("Price")
plt.show()

# %%
# If Date column exists
if "Date" in df.columns:
    df["Date"] = pd.to_datetime(df["Date"])
    daily_sales = df.groupby("Date")["TotalAmount"].sum()

    plt.figure()
    daily_sales.plot()
    plt.title("Sales Trend Over Time")
    plt.savefig("sales_trend.png")
    plt.close()

print("EDA Completed. Images saved.")
# Out:
# EDA Completed. Images saved.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Aman chauhan\\Retail-Sales-Data-Analysis\\notebook'
